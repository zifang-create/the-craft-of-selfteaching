# %%
def greet_historical_figure(name, dynasty="未知", achievement=""):
    """问候历史人物"""
    
    # 先写最简单的版本
    print(f"欢迎 {name}！")

# %%
greet_historical_figure("李白")
greet_historical_figure("诸葛亮", "三国")
# Out:
# 欢迎 李白！
# 欢迎 诸葛亮！
