# %%
在学习课程内容的过程里，记录学习过程中遇到的不同的内容、问题，如果有新的理解，就同样记录起来，进行迭代升级。

这样的做的好处，就是以后即使忘记了具体内容，但是可以快速索引到自己问题的针对性解决方法。

真的后悔为什么没有早点醒悟出这一点。
# Out:
#   Cell In[2], line 1
#     在学习课程内容的过程里，记录学习过程中遇到的不同的内容、问题，如果有新的理解，就同样记录起来，进行迭代升级。
#                ^
# SyntaxError: invalid character '，' (U+FF0C)

# %% [markdown]
# 问题一：git到库的流程和模式
# 还不够熟练
