# %%
因素数碰到的数学问题
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 因素数碰到的数学问题
#
# NameError: name '因素数碰到的数学问题' is not defined

# %%
因数是成对出现的，只要检查了左边的因数，右边的自然可以忽略
# Out:
#   Cell In[3], line 1
#     因数是成对出现的，只要检查了左边的因数，右边的自然可以忽略
#             ^
# SyntaxError: invalid character '，' (U+FF0C)

# %% [markdown]
# 36
# 2*12
# 3*12
# 4*9
# 6*6

# %%
由此可以证明，(n**0.5)
