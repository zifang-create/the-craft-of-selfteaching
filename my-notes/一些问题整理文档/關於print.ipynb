# %%
關於print和函數一些不熟悉的地方
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 關於print和函數一些不懂的地方
#
# NameError: name '關於print和函數一些不懂的地方' is not defined

# %%
"输出到屏幕的内容" 和 "函数的返回值" 是两回事！

print(1) 做了两件事：

把 1 显示在屏幕上（这是它的副作用）
然后返回 None（这是它的返回值）

外面的 print() 拿到的是返回值，不是屏幕上显示的内容。
