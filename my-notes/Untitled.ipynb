# %%
print("notes test")
# Out:
# notes test

# %% [markdown]
# ## 测试
# 这是我的笔记。

# %% [markdown]
# # 章节标题
#
# ## 1. 作者在解决什么问题？
#
# （用你自己的话写，不要抄书）
#
# ## 2. 作者给出的核心方法是什么？
#
# （列出 1–3 点）
#
# ## 3. 这和我过去的学习方式有什么不同？
#
# （对比式思考）
#
# ## 4. 我能不能用自己的例子解释？
#
# （举例说明）
#
# ## 5. 实验验证（可选）

# %% [markdown]
# ## 作者在解决什么问题？
